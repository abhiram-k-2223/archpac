# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get('https://archlinux.org/packages/',headers = headers).text

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="#08C" name="theme-color"/>
#   <title>
#    Arch Linux - Package Search
#   </title>
#   <link href="/static/archweb.fdd0941a955d.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/static/favicon.51c13517c44c.png" rel="icon" type="image/png"/>
#   <link href="/static/favicon.51c13517c44c.png" rel="shortcut icon" type="image/png"/>
#   <link href="/static/logos/apple-touch-icon-57x57.0cd0ab3349e2.png" rel="apple-touch-icon"/>
#   <link href="/static/logos/apple-touch-icon-72x72.e502bac6368f.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/static/logos/apple-touch-icon-114x114.343cca8f850e.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/static/logos/apple-touch-icon-144x144.38cf584757c3.png" rel="apple-touch-icon" sizes="144x144"/>
# ...

# %%
link = soup.find_all('a')
for i in link[15:]:
  print(i.text.strip())
# Out:
# 0ad
# 0ad
# 0ad-data
# 389-ds-base
# 3cpio
# 4ti2
# 6tunnel
# 7zip
# 9base
# a2jmidid
# a2ps
# a52dec
# aalib
# aarch64-linux-gnu-binutils
# aarch64-linux-gnu-gcc
# aarch64-linux-gnu-gdb
# aarch64-linux-gnu-glibc
# aarch64-linux-gnu-linux-api-headers
# aardvark-dns
# abc
# abcmidi
# abduco
# abi-compliance-checker
# abi-dumper
# abiword
# abletonlink
# abseil-cpp
# abuild
# accerciser
# accessibility-inspector
# accounts-qml-module
# accountsservice
# ack
# acl
# acme
# acme-redirect
# acme-tiny
# acme-user
# acme.sh
# acorn
# acpi
# acpi_call
# acpi_call-dkms
# acpi_call-lts
# acpi_call-lts
# acpica
# acpid
# acpilight
# acsccid
# act
# actionlint
# activity-log-manager
# ada
# adapta-gtk-theme
# add-determinism
# adguardhome
# adios2
# adljack
# adlplug
# adlplug-lv2
# adlplug-standalone
# adlplug-vst
# adns
# adobe-source-code-pro-fonts
# adobe-source-han-sans-cn-fonts
# adobe-source-han-sans-hk-fonts
# adobe-source-han-sans-jp-fonts
# adobe-source-han-sans-kr-fonts
# ...

# %%
a = [1,2,3,4,5,6]
for i in range(3,len(a)):
  print(a[i])
# Out:
# 4
# 5
# 6

# %%
soup.find('tbody')
# Out:
# <tbody>
# <tr>
# <td>x86_64</td>
# <td>Extra</td>
# <td><a href="/packages/extra/x86_64/0ad/" title="View package details for 0ad">0ad</a></td>
# <td>a26-18</td>
# <td class="wrap">Cross-platform, 3D and historically-based real-time strategy game</td>
# <td>2024-11-25</td>
# <td></td>
# </tr>
# <tr>
# <td>x86_64</td>
# <td>Extra-Testing</td>
# <td><a href="/packages/extra-testing/x86_64/0ad/" title="View package details for 0ad">0ad</a></td>
# <td>a26-19</td>
# <td class="wrap">Cross-platform, 3D and historically-based real-time strategy game</td>
# <td>2025-01-19</td>
# <td></td>
# </tr>
# <tr>
# <td>any</td>
# <td>Extra</td>
# <td><a href="/packages/extra/any/0ad-data/" title="View package details for 0ad-data">0ad-data</a></td>
# <td>a26-2</td>
# <td class="wrap">Cross-platform, 3D and historically-based real-time strategy game (data files)</td>
# <td>2024-07-16</td>
# <td></td>
# </tr>
# <tr>
# <td>x86_64</td>
# <td>Extra</td>
# ...

# %%
#for extras repository
extra = []

for j in range(1,94):
  headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
  page = requests.get('https://archlinux.org/packages/?page={}&sort=&arch=x86_64&repo=Extra&q=&maintainer=&flagged='.format(j)).text
  soup = BeautifulSoup(page,'lxml')
  tbody = soup.find('tbody')

  for row in tbody.find_all('tr'):
    links = row.find_all('a')
    for link in links:
        extra.append(link.text.strip())

# %%
with open('extra.json', 'w', encoding='utf-8') as f:
    json.dump(extra, f, ensure_ascii=False, indent=4)

# %%
#for extra-testing repository
extra_testing = []

for j in range(1,4):
  #headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
  page = requests.get('https://archlinux.org/packages/?page={}&sort=&arch=x86_64&repo=Extra-Testing&q=&maintainer=&flagged='.format(j)).text
  soup = BeautifulSoup(page,'lxml')
  tbody = soup.find('tbody')

  for row in tbody.find_all('tr'):
    links = row.find_all('a')
    for link in links:
        extra_testing.append(link.text.strip())

# %%
with open('extra_testing.json', 'w', encoding='utf-8') as f:
    json.dump(extra_testing, f, ensure_ascii=False, indent=4)

# %%
#for core repository
core = []

for j in range(1,4):
  #headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
  page = requests.get('https://archlinux.org/packages/?page={}&sort=&arch=x86_64&repo=Core&q=&maintainer=&flagged='.format(j)).text
  soup = BeautifulSoup(page,'lxml')
  tbody = soup.find('tbody')

  for row in tbody.find_all('tr'):
    links = row.find_all('a')
    for link in links:
        core.append(link.text.strip())

print(len(core))

with open('core.json', 'w', encoding='utf-8') as f:
    json.dump(core, f, ensure_ascii=False, indent=4)
# Out:
# 236

# %%
#for core-testing repository
#headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

core_testing = []

page = requests.get('https://archlinux.org/packages/?sort=&arch=x86_64&repo=Core-Testing&q=&maintainer=&flagged=').text
soup = BeautifulSoup(page,'lxml')
tbody = soup.find('tbody')

for row in tbody.find_all('tr'):
  links = row.find_all('a')
  for link in links:
      core_testing.append(link.text.strip())

with open('core_testing.json', 'w', encoding='utf-8') as f:
    json.dump(core_testing, f, ensure_ascii=False, indent=4)

# %%
gnome_unstable = []
page = requests.get('https://archlinux.org/packages/?sort=&arch=x86_64&repo=Gnome-Unstable&q=&maintainer=&flagged=').text
soup = BeautifulSoup(page,'lxml')
tbody = soup.find('tbody')

for row in tbody.find_all('tr'):
  links = row.find_all('a')
  for link in links:
      gnome_unstable.append(link.text.strip())

print(len(gnome_unstable))

with open('gnome_unstable.json', 'w', encoding='utf-8') as f:
    json.dump(gnome_unstable, f, ensure_ascii=False, indent=4)
# Out:
# 58

# %%
#for kde unstable repositories

kde_unstable = []

page = requests.get('https://archlinux.org/packages/?sort=&arch=x86_64&repo=KDE-Unstable&q=&maintainer=&flagged=').text
soup = BeautifulSoup(page,'lxml')
tbody = soup.find('tbody')

for row in tbody.find_all('tr'):
  links = row.find_all('a')
  for link in links:
      kde_unstable.append(link.text.strip())

print(len(kde_unstable))

with open('kde_unstable.json', 'w', encoding='utf-8') as f:
    json.dump(kde_unstable, f, ensure_ascii=False, indent=4)
# Out:
# 100

# %%
#for multilib repository
multilib = []

for j in range(1,4):
  #headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
  page = requests.get('https://archlinux.org/packages/?page={}&sort=&arch=x86_64&repo=Multilib&q=&maintainer=&flagged='.format(j)).text
  soup = BeautifulSoup(page,'lxml')
  tbody = soup.find('tbody')

  for row in tbody.find_all('tr'):
    links = row.find_all('a')
    for link in links:
        multilib.append(link.text.strip())

print(len(multilib))

with open('multilib.json', 'w', encoding='utf-8') as f:
    json.dump(multilib, f, ensure_ascii=False, indent=4)
# Out:
# 285

# %%
core_testing_packs = {}

for j in core_testing:
  page = requests.get('https://archlinux.org/packages/core-testing/x86_64/{}/').format(j).text
  soup = BeautifulSoup(page,'lxml')
  data = {

  }
# Out:
# linux-lts
# linux-lts-docs
# linux-lts-headers
# texinfo

# %%
# page = requests.get('https://archlinux.org/packages/core-testing/x86_64/linux-lts/').text
# # Access the content of the response using .content or .text
# soup = BeautifulSoup(page,'lxml')


page = requests.get('https://archlinux.org/packages/extra-testing/x86_64/0ad/').text
soup = BeautifulSoup(page, 'lxml')
pkg_details = soup.find(id='pkgdetails')

data_dict = {}

title = soup.find('h2').text

for item in pkg_details.find_all('tr'):
    th = item.find('th').text.strip() if item.find('th') else None
    td = item.find('td').text.strip() if item.find('td') else None

    if th and td:
        th = th.replace('\n', ' ').replace('\xa0', ' ').strip()
        td = td.replace('\n', ' ').replace('\xa0', ' ').strip()
        data_dict[th] = td

data = {
    "title": title
}
data.update(data_dict)

json_data = json.dumps(data, indent=4)
print(json_data)
# Out:
# {
#     "title": "0ad a26-19",
#     "Architecture:": "x86_64",
#     "Repository:": "Extra-Testing",
#     "Description:": "Cross-platform, 3D and historically-based real-time strategy game",
#     "Upstream URL:": "http://play0ad.com/",
#     "License(s):": "CCPL, GPL-2.0-or-later",
#     "Maintainers:": "Sven-Hendrik Haase",
#     "Package Size:": "14.1 MB",
#     "Installed Size:": "46.7 MB",
#     "Last Packager:": "Antonio Rojas",
#     "Build Date:": "2025-01-18 23:36 UTC",
#     "Signed By:": "Antonio Rojas",
#     "Signature Date:": "2025-01-18 23:42 UTC",
#     "Last Updated:": "2025-01-19 10:38 UTC"
# }

# %%
{
  "prompt": "what can i for a GNU documentation system for on-line information and printed output",
   "response":{
      "title": "texinfo 7.2-1",
      "details": {
          "Architecture:": "x86_64",
          "Repository:": "Core-Testing",
          "Description:": "GNU documentation system for on-line information and printed output",
          "Upstream URL:": "https://www.gnu.org/software/texinfo/",
          "License(s):": "GPL3",
          "Maintainers:": "Frederik Schwan",
          "Package Size:": "2.0 MB",
          "Installed Size:": "11.5 MB",
          "Last Packager:": "Frederik Schwan",
          "Build Date:": "2024-12-28 13:17 UTC",
          "Signed By:": "Frederik Schwan",
          "Signature Date:": "2024-12-28 13:19 UTC",
          "Last Updated:": "2024-12-28 13:27 UTC"
      }
  }
}
# Out:
#   File "<ipython-input-1-04d640e49278>", line 3
#     Description: 	Cross-platform, 3D and historically-based real-time strategy game
#                  	                ^
# SyntaxError: invalid decimal literal

# %%
prompt_examples = [
    "What software can I use for ",
    "I need a tool for ",
    "Suggest me software for ",
    "Is there a package for ",
    "I want a program that does ",
    "Find me software related to ",
    "Can you recommend a tool for ",
    "Is there something I can use for ",
    "What can I install for ",
    "Are there any programs for ",
    "Help me find software for ",
    "Do you know a package for ",
    "What are the tools available for ",
    "Can you help me discover software for ",
    "I need help finding a package for ",
    "Which package should I install for ",
    "What program should I use for ",
    "Any recommendations for software to ",
    "What is a good option for "
]

# %%
with open('core.json', 'r') as file:
    core_data = json.load(file)

print(core_data)
# Out:
# ['acl', 'attr', 'audit', 'b43-fwcutter', 'bash', 'binutils', 'bison', 'brotli', 'brotli-testdata', 'btrfs-progs', 'bzip2', 'ca-certificates-mozilla', 'coreutils', 'cracklib', 'cryptsetup', 'curl', 'dash', 'db', 'db5.3', 'dbus', 'dbus-broker', 'dbus-broker-units', 'dbus-daemon-units', 'dbus-docs', 'dbus-units', 'debugedit', 'debuginfod', 'device-mapper', 'dialog', 'diffutils', 'ding-libs', 'dmraid', 'dosfstools', 'e2fsprogs', 'efibootmgr', 'efivar', 'elfutils', 'expat', 'fakeroot', 'file', 'findutils', 'flex', 'fuse2fs', 'gawk', 'gc', 'gcc', 'gcc-ada', 'gcc-d', 'gcc-fortran', 'gcc-go', 'gcc-libs', 'gcc-m2', 'gcc-objc', 'gcc-rust', 'gdbm', 'gettext', 'glib2', 'glib2-devel', 'glib2-docs', 'glibc', 'glibc-locales', 'gmp', 'gnupg', 'gnutls', 'gpgme', 'gpm', 'grep', 'groff', 'grub', 'gssproxy', 'guile', 'gzip', 'hdparm', 'icu', 'inetutils', 'iproute2', 'iptables', 'iptables-nft', 'iputils', 'iw', 'jansson', 'jfsutils', 'json-c', 'kbd', 'keyutils', 'kmod', 'krb5', 'ldns', 'lemon', 'less', '
# ...

# %%
all_data = []

for j in core_data:
    page = requests.get('https://archlinux.org/packages/core/x86_64/{}/'.format(j)).text
    soup = BeautifulSoup(page, 'lxml')
    pkg_details = soup.find(id='pkgdetails')

    data_dict = {}

    title = soup.find('h2').text

    for item in pkg_details.find_all('tr'):
        th = item.find('th').text.strip() if item.find('th') else None
        td = item.find('td').text.strip() if item.find('td') else None

        if th and td:
            th = th.replace('\n', ' ').replace('\xa0', ' ').strip()
            td = td.replace('\n', ' ').replace('\xa0', ' ').strip()
            data_dict[th] = td

    data = {
        "title": title
    }
    data.update(data_dict)

    all_data.append(data)

with open('core-packs.json', 'w', encoding='utf-8') as f:
    json.dump(all_data, f, ensure_ascii=False, indent=4)

# %%
with open('core_testing.json', 'r') as file:
    core_testing_data = json.load(file)

core_testing_packs = []

for j in core_testing_data:
    page = requests.get('https://archlinux.org/packages/core-testing/x86_64/{}/'.format(j)).text
    soup = BeautifulSoup(page, 'lxml')
    pkg_details = soup.find(id='pkgdetails')

    data_dict = {}

    title = soup.find('h2').text

    for item in pkg_details.find_all('tr'):
        th = item.find('th').text.strip() if item.find('th') else None
        td = item.find('td').text.strip() if item.find('td') else None

        if th and td:
            th = th.replace('\n', ' ').replace('\xa0', ' ').strip()
            td = td.replace('\n', ' ').replace('\xa0', ' ').strip()
            data_dict[th] = td

    data = {
        "title": title
    }
    data.update(data_dict)

    core_testing_packs.append(data)

with open('core_testing_packs.json', 'w', encoding='utf-8') as f:
    json.dump(core_testing_packs, f, ensure_ascii=False, indent=4)

# %%
with open('extra_testing.json', 'r') as file:
    extra_testing_data = json.load(file)

extra_testing_packs = []

for j in extra_testing_data:
    page = requests.get('https://archlinux.org/packages/extra-testing/x86_64/{}/'.format(j)).text
    soup = BeautifulSoup(page, 'lxml')
    pkg_details = soup.find(id='pkgdetails')

    data_dict = {}

    title = soup.find('h2').text

    for item in pkg_details.find_all('tr'):
        th = item.find('th').text.strip() if item.find('th') else None
        td = item.find('td').text.strip() if item.find('td') else None

        if th and td:
            th = th.replace('\n', ' ').replace('\xa0', ' ').strip()
            td = td.replace('\n', ' ').replace('\xa0', ' ').strip()
            data_dict[th] = td
    data = {
        "title": title
    }
    data.update(data_dict)

    extra_testing_packs.append(data)

with open('extra_testing_packs.json', 'w', encoding='utf-8') as f:
    json.dump(extra_testing_packs, f, ensure_ascii=False, indent=4)

# %%
with open('multilib.json', 'r') as file:
    multilib_data = json.load(file)

multilib_packs = []

for j in multilib_data:
    page = requests.get('https://archlinux.org/packages/multilib/x86_64/{}/'.format(j)).text
    soup = BeautifulSoup(page, 'lxml')
    pkg_details = soup.find(id='pkgdetails')

    data_dict = {}

    title = soup.find('h2').text

    for item in pkg_details.find_all('tr'):
        th = item.find('th').text.strip() if item.find('th') else None
        td = item.find('td').text.strip() if item.find('td') else None

        if th and td:
            th = th.replace('\n', ' ').replace('\xa0', ' ').strip()
            td = td.replace('\n', ' ').replace('\xa0', ' ').strip()
            data_dict[th] = td
    data = {
        "title": title
    }
    data.update(data_dict)

    multilib_packs.append(data)

with open('multilib_packs.json', 'w', encoding='utf-8') as f:
    json.dump(multilib_packs, f, ensure_ascii=False, indent=4)

# %%
with open('gnome_unstable.json', 'r') as file:
    gnome_unstable_data = json.load(file)

gnome_unstable_packs = []

for j in gnome_unstable_data:
    page = requests.get('https://archlinux.org/packages/gnome-unstable/x86_64/{}/'.format(j)).text
    soup = BeautifulSoup(page, 'lxml')
    pkg_details = soup.find(id='pkgdetails')

    data_dict = {}

    title = soup.find('h2').text

    for item in pkg_details.find_all('tr'):
        th = item.find('th').text.strip() if item.find('th') else None
        td = item.find('td').text.strip() if item.find('td') else None

        if th and td:
            th = th.replace('\n', ' ').replace('\xa0', ' ').strip()
            td = td.replace('\n', ' ').replace('\xa0', ' ').strip()
            data_dict[th] = td
    data = {
        "title": title
    }
    data.update(data_dict)

    gnome_unstable_packs.append(data)

with open('gnome_unstable_packs.json', 'w', encoding='utf-8') as f:
    json.dump(gnome_unstable_packs, f, ensure_ascii=False, indent=4)

# %%
with open('kde_unstable.json', 'r') as file:
    kde_unstable_data = json.load(file)

kde_unstable_packs = []

for j in kde_unstable_data:
    page = requests.get('https://archlinux.org/packages/kde-unstable/x86_64/{}/'.format(j)).text
    soup = BeautifulSoup(page, 'lxml')
    pkg_details = soup.find(id='pkgdetails')

    data_dict = {}

    title = soup.find('h2').text

    for item in pkg_details.find_all('tr'):
        th = item.find('th').text.strip() if item.find('th') else None
        td = item.find('td').text.strip() if item.find('td') else None

        if th and td:
            th = th.replace('\n', ' ').replace('\xa0', ' ').strip()
            td = td.replace('\n', ' ').replace('\xa0', ' ').strip()
            data_dict[th] = td
    data = {
        "title": title
    }
    data.update(data_dict)

    kde_unstable_packs.append(data)

with open('kde_unstable_packs.json', 'w', encoding='utf-8') as f:
    json.dump(kde_unstable_packs, f, ensure_ascii=False, indent=4)

# %%
with open('extra.json', 'r') as file:
    extra_data = json.load(file)

extra_packs = []

for j in extra_data:
    page = requests.get('https://archlinux.org/packages/extra/x86_64/{}/'.format(j)).text
    soup = BeautifulSoup(page, 'html.parser')
    pkg_details = soup.find(id='pkgdetails')

    data_dict = {}

    title = soup.find('h2').text

    for item in pkg_details.find_all('tr'):
        th = item.find('th').text.strip() if item.find('th') else None
        td = item.find('td').text.strip() if item.find('td') else None

        if th and td:
            th = th.replace('\n', ' ').replace('\xa0', ' ').strip()
            td = td.replace('\n', ' ').replace('\xa0', ' ').strip()
            data_dict[th] = td
    data = {
        "title": title
    }
    data.update(data_dict)

    extra_packs.append(data)

with open('extra_packs.json', 'w', encoding='utf-8') as f:
    json.dump(extra_packs, f, ensure_ascii=False, indent=4)
